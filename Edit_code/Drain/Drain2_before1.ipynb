# %%
# Khai báo sử dụng các thư viện. Thực hiện chạy ngay trên CPU, do đó, chỉ thực hiện mô phỏng, nếu ổn định sẽ thực hiện chạy trên kaggle
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sys

import regex as re
import os
import hashlib
from datetime import datetime
import hashlib
import copy

from tabulate import tabulate # Thư viện sử dụng hiển thị dữ liệu dạng bảng cho DataFrame

from openpyxl import load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Chỉnh sửa class Logcluster:
from Root_Drain import LogParser, Node, Logcluster            # Source code cũ của Drain

class Logcluster3(Logcluster):
    """
    Class được chỉnh sửa lại, bao gồm một số thông số như sau:
    
    Thuộc tính:
    ----------
        - `logTemplate`: Template đặc trưng đại diện cho nhóm log đó, ["The1", "the2", ...]
        - `logIDL`     : Danh sách các ID message log thuộc nhóm log trên, [1,2,3,4,5, ...] 
        - `levelL`     : Danh sách các Level (INFO, WARN, FATAL, ERROR) mà nhóm log có thể biểu diễn, ["WARN", "INFO", ...]
        - `idTemplate` : Mã định danh của template đó, có thể bị thay đổi do template.
        - `idLevelTemp`: Xác định mã định danh theo dạng {"INFO": "L1", ...} 
    """
    def __init__(self, logTemplate="", levelL=None, logIDL=None):
        self.logTemplate = logTemplate
        if logIDL is None:
            logIDL = []
        self.logIDL = logIDL
        self.levelL = list(levelL)
        self.idTemplate = None
        self.idLevelTemp = {"TEMP":None}
        
    def addIDLevel(self, logLevel):
        self.levelL.append(logLevel)

# %%
# Thực hiện chỉnh sửa lại 2 phương thức outputResult() và parser() của Drain:
# Kế thừa Drain bằng cách tạo ra class Drain2:
class LogParser2(LogParser):
    """
    Kế thừa từ LogParser được sử dụng để thực hiện sửa đổi lại sao cho phù hợp.
    """
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)       # Đọc thêm: https://viblo.asia/p/python-args-va-kwargs-gDVK2pdnlLj
        self.rootNode = Node()
        self.list_logClust = []
        self.list_eventsID = {}
        self.df_TemplateL = None
        self.list_counts = {"TEMP":0}
    
    def convert_unixtime(self, row):
        date_str = row["Date"]
        time_str = row["Time"]
        datetime_str = date_str[:2] + "-" + date_str[2:4] + "-" + date_str[4:] + " " + time_str[:2] + ":" + time_str[2:4] + ":" + time_str[4:]
        unixtime = datetime.strptime(datetime_str, "%m-%y-%d %H:%M:%S").timestamp()
        return int(unixtime)
    
    def outputResult(self, logClustL):
        """
        Thực hiện in thông tin kết quả ra ngoài sau khi hoàn thành quá trình phân tích
        
        Tham số:
        --------
            - `logClustL`   : Danh sách các nhóm log đã thu thập được trong quá trình phân tách
        """
        # ----------- Khai báo các biến sử dụng ----------#
        log_templates = [0] * self.df_log.shape[0]
        log_templateids = [0] * self.df_log.shape[0]
        list_events = []                            # Mảng list_events lưu giữ các giá trị template
        dictionary_events = self.list_eventsID      # Dictionary lưu giữ các đối tượng idTemplate và các thông số của nó: "idTemplate": {"TEMP":"L5", "INFO":"I2", ...}
    
        # --------------Thực hiện phân tích--------------#
        # * Duyệt qua từng đối tượng Logcluster để thêm các giá trị vào từng biến trên
        for logClust in logClustL:
            template_str = " ".join(logClust.logTemplate)
            occurrence = len(logClust.logIDL)
            template_id = hashlib.md5(template_str.encode("utf-8")).hexdigest()[0:8]
            logClust.idTemplate = template_id   # không cần cũng được
            for logID in logClust.logIDL:
                logID -= 1
                log_templates[logID] = template_str
                log_templateids[logID] = template_id
            logClust.logIDL=[]
            list_events.append([template_id, template_str, occurrence, logClust.levelL, logClust.idLevelTemp])
            if template_id not in dictionary_events:
                dictionary_events[template_id] = logClust.idLevelTemp

        # DataFrame df_event lưu giữ các thông tin của Template
        df_event = pd.DataFrame(
            list_events, columns=["EventId", "EventTemplate", "Occurrences", "logLevel", "IDlogLevel"]
        )
        # varL1.df_all_events = df_event
        
        # DataFrame df_log lưu giữ các thông tin của từng dòng thông điệp log
        self.df_log["EventId"] = log_templateids
        self.df_log["EventTemplate"] = log_templates
        
        # Chuyển đổi thời gian theo dạng UnixTime:
        # Tạo thêm cột "UnixTime" trong DataFrame: df_log
        self.df_log["UnixTime"] = self.df_log.apply(self.convert_unixtime, axis=1)
                
        if self.keep_para:
            self.df_log["ParameterList"] = self.df_log.apply(
                self.get_parameter_list, axis=1
            )
        self.df_log["IDLevel"] = self.df_log.apply(
            lambda row: dictionary_events.get(row["EventId"], {}).get(row["Level"], None),
            axis=1
        )
        self.df_log["LineId2"] = self.df_log.apply(
            lambda row: dictionary_events.get(row["EventId"], {}).get("TEMP", None),
            axis=1
        )
    
    def parse(self, logName):
        """
        Phương thức thực hiện quá trình phân tích log
        
        Tham số: 
        --------
            - `logName`: Tên file đầu vào thực hiện phân tích
        """
        print("File đầu vào: " + os.path.join(self.path, logName))
        start_time = datetime.now()
        self.logName = logName

        # ------Gán lại các đối tượng sử dụng--------#
        rootNode = self.rootNode       # Địa chỉ Node gốc
        logCluL = self.list_logClust   # Lưu giữ các đối tượng nhóm log Logcluster2 trước đó.
        templateLogCluL = []           # Lưu giữ các template đã có trước đó.

        # ----------------Load dữ liệu---------------#
        self.load_data() 

        #-----------------Phân tích------------------#
        # * Gán giá trị cho danh sách đếm template:
        unique_Level = self.df_log["Level"].unique()
        for value in unique_Level:
            if value not in self.list_counts:
                self.list_counts[value] = 0

        # * Thực hiện phân tích và lấy Template cho từng dòng thông điệp log
        count = 0
        for idx, line in self.df_log.iterrows(): 
            logLevel = str(line["Level"])
            logID = line["LineId"]
            logmessageL = self.preprocess(line["Content"]).strip().split()  
            matchCluster = self.treeSearch(rootNode, logmessageL)           
            if matchCluster is None:
                newCluster = Logcluster3(logTemplate=logmessageL, levelL=[logLevel], logIDL=[logID])
                
                # - Nếu có template mới, tạo ra, tăng biến đếm, gán id level template cho mẫu:
                self.list_counts["TEMP"] += 1
                self.list_counts[logLevel] += 1
                newCluster.idLevelTemp["TEMP"] = "L"+ str(self.list_counts["TEMP"])
                newCluster.idLevelTemp[logLevel] = logLevel[0] + str(self.list_counts[logLevel])
                
                # - Thêm chúng vào cây phân tích
                logCluL.append(newCluster)
                self.addSeqToPrefixTree(rootNode, newCluster)
            else:
                # - Nếu template đã có:
                newTemplate = self.getTemplate(logmessageL, matchCluster.logTemplate)
                matchCluster.logIDL.append(logID)
                # + Nếu có sự thay đổi trong template thành một template mới, cập nhật
                if " ".join(newTemplate) != " ".join(matchCluster.logTemplate):
                    matchCluster.logTemplate = newTemplate
                    
                # + Nếu có thêm một level mới biểu diễn template này, cập nhật nó
                if logLevel not in matchCluster.levelL:
                    matchCluster.addIDLevel(logLevel)
                    self.list_counts[logLevel] += 1
                    matchCluster.idLevelTemp[logLevel] = logLevel[0] + str(self.list_counts[logLevel])
                    
            count += 1
            if count % 100000 == 0 or count == len(self.df_log):
                print("Processed {0:.1f}% of log lines.".format(count * 100.0 / len(self.df_log))) # Chỉ sửa mỗi vị trí này.

        # if not os.path.exists(self.savePath):
        #     os.makedirs(self.savePath)
        self.outputResult(self.list_logClust)
        print("Phân tích hoàn thành! [Thời gian thực hiện: {!s}]".format(datetime.now() - start_time))

# %%
input_dir  = '../../Dataset/HDFS/v1/'   # Đường dẫn vào thư mục chứa file đầu vào
output_dir = 'Result/'                  # Thư mục kết quả
log_file   = 'test2.log'                 # Tên file đầu vào
log_format = '<Date> <Time> <Pid> <Level> <Component>: <Content>'  # HDFS log format
# Biểu thức chính quy
regex      = [
    r'blk_(|-)[0-9]+' , # block id
    r'(/|)([0-9]+\.){3}[0-9]+(:[0-9]+|)(:|)', # IP
    r'(?<=[^A-Za-z0-9])(\-?\+?\d+)(?=[^A-Za-z0-9])|[0-9]+$', # Numbers
]
st         = 0.5  # Ngưỡng tương đồng
depth      = 4  # Độ sâu của cây phân tích

parserObj = LogParser2(log_format, indir=input_dir, outdir=output_dir, depth=depth, st=st, rex=regex)
# parserObj.parse(log_file)

selected_columns = ['LineId', 'Level', 'EventId', 'EventTemplate', 'IDLevel', 'LineId2']
for i in range(1,6):
    str_file = "test"+str(i)+".log"
    parserObj.parse(str_file)
    # outputResult2(parserObj.list_logClust)
    parserObj.df_log.loc[:, selected_columns].head(60)
    parserObj.df_log = pd.DataFrame()

# %%
# Chỉnh sửa lại phương thức parser trong LogParser, chỉnh sửa trực tiếp
def parser22(log_f):
    log_file=log_f
    logName = log_file

    print("File đầu vào: " + os.path.join(parserObj.path, logName))
    start_time = datetime.now()
    parserObj.logName = logName

    # ------Gán lại các đối tượng sử dụng--------#
    rootNode = parserObj.rootNode       # Địa chỉ Node gốc
    logCluL = parserObj.list_logClust   # Lưu giữ các đối tượng nhóm log Logcluster2 trước đó.
    templateLogCluL = []                # Lưu giữ các template đã có trước đó.

    # ----------------Load dữ liệu---------------#
    parserObj.load_data() 

    #-----------------Phân tích------------------#
    # * Gán giá trị cho danh sách đếm template:
    unique_Level = parserObj.df_log["Level"].unique()
    for value in unique_Level:
        if value not in parserObj.list_counts:
            parserObj.list_counts[value] = 0

    # * Thực hiện phân tích và lấy Template cho từng dòng thông điệp log
    count = 0
    for idx, line in parserObj.df_log.iterrows(): 
        logLevel = str(line["Level"])
        logID = line["LineId"]
        logmessageL = parserObj.preprocess(line["Content"]).strip().split()  
        matchCluster = parserObj.treeSearch(rootNode, logmessageL)           
        if matchCluster is None:
            newCluster = Logcluster3(logTemplate=logmessageL, levelL=[logLevel], logIDL=[logID])
            
            # - Nếu có template mới, tạo ra, tăng biến đếm, gán id level template cho mẫu:
            parserObj.list_counts["TEMP"] += 1
            parserObj.list_counts[logLevel] += 1
            newCluster.idLevelTemp["TEMP"] = "L"+ str(parserObj.list_counts["TEMP"])
            newCluster.idLevelTemp[logLevel] = logLevel[0] + str(parserObj.list_counts[logLevel])
            
            # - Thêm chúng vào cây phân tích
            logCluL.append(newCluster)
            parserObj.addSeqToPrefixTree(rootNode, newCluster)
        else:
            # - Nếu template đã có:
            newTemplate = parserObj.getTemplate(logmessageL, matchCluster.logTemplate)
            matchCluster.logIDL.append(logID)
            # + Nếu có sự thay đổi trong template thành một template mới, cập nhật
            if " ".join(newTemplate) != " ".join(matchCluster.logTemplate):
                matchCluster.logTemplate = newTemplate
                
            # + Nếu có thêm một level mới biểu diễn template này, cập nhật nó
            if logLevel not in matchCluster.levelL:
                matchCluster.addIDLevel(logLevel)
                parserObj.list_counts[logLevel] += 1
                matchCluster.idLevelTemp[logLevel] = logLevel[0] + str(parserObj.list_counts[logLevel])
                
        count += 1
        if count % 100000 == 0 or count == len(parserObj.df_log):
            print("Processed {0:.1f}% of log lines.".format(count * 100.0 / len(parserObj.df_log))) # Chỉ sửa mỗi vị trí này.
    # parserObj.list_logClust = copy.deepcopy(logCluL)

    # if not os.path.exists(self.savePath):
    #     os.makedirs(self.savePath)
    # self.outputResult(logCluL)
    print("Phân tích hoàn thành! [Thời gian thực hiện: {!s}]".format(datetime.now() - start_time))

# for i in range(1,6):
#     str_file = "test"+str(i)+".log"
#     parser22(str_file)

# %% [markdown]
# ##### Thực hiện tạo ra một dictionary như sau:
# ##### - {"idTamplate": "L1", ...}

# %%
# Thực hiện sửa lại phương thức outputResult, viết trực tiếp để dễ chỉnh sửa:
# Class này chỉ để lưu thông tin.
class varL:
    def __init__(self):
        df_all_events = pd.DataFrame()
        df_all_events2 = pd.DataFrame()

varL1 = varL()


# def levelTempID(row):
#     return dictionary_events[row["EventId"]][row["Level"]]
# def alternateTempID(row):
#     return dictionary_events[row["EventId"]]["TEMP"]

def outputResult2(logClustL):
    # ----------- Khai báo các biến sử dụng ----------#
    log_templates = [0] * parserObj.df_log.shape[0]
    log_templateids = [0] * parserObj.df_log.shape[0]
    list_events = []  # Mảng list_events lưu giữ các giá trị template
    dictionary_events = parserObj.list_eventsID   # Dictionary lưu giữ các đối tượng idTemplate và các thông số của nó: "idTemplate": {"TEMP":"L5", "INFO":"I2", ...}
   
    # --------------Thực hiện phân tích--------------#
    # * Duyệt qua từng đối tượng Logcluster để thêm các giá trị vào từng biến trên
    for logClust in logClustL:
        template_str = " ".join(logClust.logTemplate)
        occurrence = len(logClust.logIDL)
        template_id = hashlib.md5(template_str.encode("utf-8")).hexdigest()[0:8]
        logClust.idTemplate = template_id   # không cần cũng được
        for logID in logClust.logIDL:
            logID -= 1
            log_templates[logID] = template_str
            log_templateids[logID] = template_id
        logClust.logIDL=[]
        list_events.append([template_id, template_str, occurrence, logClust.levelL, logClust.idLevelTemp])
        if template_id not in dictionary_events:
            dictionary_events[template_id] = logClust.idLevelTemp

    # DataFrame df_event lưu giữ các thông tin của Template
    df_event = pd.DataFrame(
        list_events, columns=["EventId", "EventTemplate", "Occurrences", "logLevel", "IDlogLevel"]
    )
    varL1.df_all_events = df_event
    
    # DataFrame df_log lưu giữ các thông tin của từng dòng thông điệp log
    parserObj.df_log["EventId"] = log_templateids
    parserObj.df_log["EventTemplate"] = log_templates
            
    if parserObj.keep_para:
        parserObj.df_log["ParameterList"] = parserObj.df_log.apply(
            parserObj.get_parameter_list, axis=1
        )
    parserObj.df_log["IDLevel"] = parserObj.df_log.apply(
        lambda row: dictionary_events.get(row["EventId"], {}).get(row["Level"], None),
        axis=1
    )
    parserObj.df_log["LineId2"] = parserObj.df_log.apply(
        lambda row: dictionary_events.get(row["EventId"], {}).get("TEMP", None),
        axis=1
    )
# varL1.df_all_events.head(30)
selected_columns = ['LineId', 'Level', 'EventId', 'EventTemplate', 'IDLevel', 'LineId2']
for i in range(1,6):
    str_file = "test"+str(i)+".log"
    parser22(str_file)
    outputResult2(parserObj.list_logClust)
    parserObj.df_log.loc[:, selected_columns].head(60)
    parserObj.df_log = pd.DataFrame()

# selected_columns = ['LineId', 'Level', 'EventId', 'EventTemplate', 'IDLevel', 'LineId2']
# print(parserObj.df_log.columns)
# parserObj.df_log.loc[:, selected_columns].head(60)
# Out:
# File đầu vào: ../../Dataset/HDFS/v1/test1.log
# Total lines:  200500
# Processed 49.9% of log lines.
# Processed 99.8% of log lines.
# Processed 100.0% of log lines.
# Phân tích hoàn thành! [Thời gian thực hiện: 0:00:13.995417]
#     LineId Level   EventId  \
# 0        1  INFO  09a53393
# 1        2  INFO  3d91fa85
# 2        3  INFO  09a53393
# 3        4  INFO  09a53393
# 4        5  INFO  d38aa58d
# 5        6  INFO  d38aa58d
# 6        7  INFO  e3df2680
# 7        8  INFO  e3df2680
# 8        9  INFO  d38aa58d
# 9       10  INFO  e3df2680
# 10      11  INFO  5d5de21c
# 11      12  INFO  5d5de21c
# 12      13  INFO  5d5de21c
# 13      14  INFO  09a53393
# 14      15  INFO  09a53393
# 15      16  INFO  3d91fa85
# 16      17  INFO  d6b7b743
# 17      18  INFO  09a53393
# 18      19  INFO  09a53393
# 19      20  INFO  09a53393
# 20      21  INFO  d38aa58d
# 21      22  INFO  e3df2680
# 22      23  INFO  d38aa58d
# 23      24  INFO  e3df2680
# 24      25  INFO  73c2ec69
# 25      26  INFO  d6b7b743
# 26      27  INFO  09a53393
# 27      28  INFO  d38aa58d
# 28      29  INFO  e3df2680
# 29      30  INFO  75627efd
# 30      31  INFO  54e5f6b4
# 31      32  INFO  5d5de21c
# 32      33  INFO  3d91fa85
# 33      34  INFO  5d5de21c
# 34      35  INFO  5d5de21c
# 35      36  INFO  5d5de21c
# 36      37  INFO  5d5de21c
# 37      38  INFO  09a53393
# 38      39  INFO  09a53393
# 39      40  INFO  d38aa58d
# 40      41  INFO  e3df2680
# 41      42  INFO  09a53393
# 42      43  INFO  d38aa58d
# 43      44  INFO  e3df2680
# 44      45  INFO  d38aa58d
# 45      46  INFO  e3df2680
# 46      47  INFO  626085d5
# 47      48  INFO  626085d5
# 48      49  INFO  3d91fa85
# 49      50  INFO  5d5de21c
# 50      51  INFO  5d5de21c
# 51      52  INFO  5d5de21c
# 52      53  INFO  09a53393
# 53      54  INFO  09a53393
# 54      55  INFO  d38aa58d
# 55      56  INFO  e3df2680
# 56      57  INFO  d38aa58d
# 57      58  INFO  e3df2680
# 58      59  INFO  d38aa58d
# 59      60  INFO  e3df2680
#
#                                                                        EventTemplate  \
# 0                                             Receiving block <*> src: <*> dest: <*>
# 1                                           BLOCK* NameSystem.allocateBlock: <*> <*>
# 2                                             Receiving block <*> src: <*> dest: <*>
# 3                                             Receiving block <*> src: <*> dest: <*>
# 4                                              PacketResponder <*> for block <*> <*>
# 5                                              PacketResponder <*> for block <*> <*>
# 6                                            Received block <*> of size <*> from <*>
# 7                                            Received block <*> of size <*> from <*>
# 8                                              PacketResponder <*> for block <*> <*>
# 9                                            Received block <*> of size <*> from <*>
# 10  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 11  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 12  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 13                                            Receiving block <*> src: <*> dest: <*>
# 14                                            Receiving block <*> src: <*> dest: <*>
# 15                                          BLOCK* NameSystem.allocateBlock: <*> <*>
# 16                                 Received block <*> src: <*> dest: <*> of size <*>
# 17                                            Receiving block <*> src: <*> dest: <*>
# 18                                            Receiving block <*> src: <*> dest: <*>
# 19                                            Receiving block <*> src: <*> dest: <*>
# 20                                             PacketResponder <*> for block <*> <*>
# 21                                           Received block <*> of size <*> from <*>
# 22                                             PacketResponder <*> for block <*> <*>
# 23                                           Received block <*> of size <*> from <*>
# 24                                                   <*>Transmitted block <*> to <*>
# 25                                 Received block <*> src: <*> dest: <*> of size <*>
# 26                                            Receiving block <*> src: <*> dest: <*>
# 27                                             PacketResponder <*> for block <*> <*>
# 28                                           Received block <*> of size <*> from <*>
# 29                             <*> Starting thread to transfer block <*> to <*>, <*>
# 30                            BLOCK* ask <*> to replicate <*> to datanode(s) <*> <*>
# 31  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 32                                          BLOCK* NameSystem.allocateBlock: <*> <*>
# 33  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 34  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 35  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 36  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 37                                            Receiving block <*> src: <*> dest: <*>
# 38                                            Receiving block <*> src: <*> dest: <*>
# 39                                             PacketResponder <*> for block <*> <*>
# 40                                           Received block <*> of size <*> from <*>
# 41                                            Receiving block <*> src: <*> dest: <*>
# 42                                             PacketResponder <*> for block <*> <*>
# 43                                           Received block <*> of size <*> from <*>
# 44                                             PacketResponder <*> for block <*> <*>
# 45                                           Received block <*> of size <*> from <*>
# 46                                                       <*> Served block <*> to <*>
# 47                                                       <*> Served block <*> to <*>
# 48                                          BLOCK* NameSystem.allocateBlock: <*> <*>
# 49  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 50  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 51  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 52                                            Receiving block <*> src: <*> dest: <*>
# 53                                            Receiving block <*> src: <*> dest: <*>
# 54                                             PacketResponder <*> for block <*> <*>
# 55                                           Received block <*> of size <*> from <*>
# 56                                             PacketResponder <*> for block <*> <*>
# 57                                           Received block <*> of size <*> from <*>
# 58                                             PacketResponder <*> for block <*> <*>
# 59                                           Received block <*> of size <*> from <*>
#
#    IDLevel LineId2
# 0       I1      L1
# 1       I2      L2
# 2       I1      L1
# 3       I1      L1
# 4       I3      L3
# 5       I3      L3
# 6       I4      L4
# 7       I4      L4
# 8       I3      L3
# 9       I4      L4
# 10      I5      L5
# 11      I5      L5
# 12      I5      L5
# 13      I1      L1
# 14      I1      L1
# 15      I2      L2
# 16      I6      L6
# 17      I1      L1
# 18      I1      L1
# 19      I1      L1
# 20      I3      L3
# 21      I4      L4
# 22      I3      L3
# 23      I4      L4
# 24      I7      L7
# 25      I6      L6
# 26      I1      L1
# 27      I3      L3
# 28      I4      L4
# 29      I8      L8
# 30      I9      L9
# 31      I5      L5
# 32      I2      L2
# 33      I5      L5
# 34      I5      L5
# 35      I5      L5
# 36      I5      L5
# 37      I1      L1
# 38      I1      L1
# 39      I3      L3
# 40      I4      L4
# 41      I1      L1
# 42      I3      L3
# 43      I4      L4
# 44      I3      L3
# 45      I4      L4
# 46     I10     L10
# 47     I10     L10
# 48      I2      L2
# 49      I5      L5
# 50      I5      L5
# 51      I5      L5
# 52      I1      L1
# 53      I1      L1
# 54      I3      L3
# 55      I4      L4
# 56      I3      L3
# 57      I4      L4
# 58      I3      L3
# 59      I4      L4
# File đầu vào: ../../Dataset/HDFS/v1/test2.log
# Total lines:  397000
# Processed 25.2% of log lines.
# Processed 50.4% of log lines.
# Processed 75.6% of log lines.
# Processed 100.0% of log lines.
# Phân tích hoàn thành! [Thời gian thực hiện: 0:00:28.229747]
#     LineId Level   EventId  \
# 0        1  INFO  09a53393
# 1        2  INFO  09a53393
# 2        3  INFO  09a53393
# 3        4  INFO  09a53393
# 4        5  INFO  09a53393
# 5        6  INFO  09a53393
# 6        7  INFO  32777b38
# 7        8  INFO  5d5de21c
# 8        9  INFO  3d91fa85
# 9       10  INFO  5d5de21c
# 10      11  INFO  5d5de21c
# 11      12  INFO  5d5de21c
# 12      13  INFO  5d5de21c
# 13      14  INFO  5d5de21c
# 14      15  INFO  5d5de21c
# 15      16  INFO  5d5de21c
# 16      17  INFO  3d91fa85
# 17      18  INFO  5d5de21c
# 18      19  INFO  5d5de21c
# 19      20  INFO  5d5de21c
# 20      21  INFO  3d91fa85
# 21      22  INFO  5d5de21c
# 22      23  INFO  5d5de21c
# 23      24  INFO  3d91fa85
# 24      25  INFO  d38aa58d
# 25      26  INFO  e3df2680
# 26      27  INFO  d38aa58d
# 27      28  INFO  e3df2680
# 28      29  INFO  d38aa58d
# 29      30  INFO  e3df2680
# 30      31  INFO  d38aa58d
# 31      32  INFO  e3df2680
# 32      33  INFO  09a53393
# 33      34  INFO  d38aa58d
# 34      35  INFO  d38aa58d
# 35      36  INFO  e3df2680
# 36      37  INFO  e3df2680
# 37      38  INFO  d38aa58d
# 38      39  INFO  e3df2680
# 39      40  INFO  d38aa58d
# 40      41  INFO  d38aa58d
# 41      42  INFO  e3df2680
# 42      43  INFO  e3df2680
# 43      44  INFO  d38aa58d
# 44      45  INFO  e3df2680
# 45      46  INFO  d38aa58d
# 46      47  INFO  e3df2680
# 47      48  INFO  d38aa58d
# 48      49  INFO  e3df2680
# 49      50  INFO  09a53393
# 50      51  INFO  d38aa58d
# 51      52  INFO  e3df2680
# 52      53  INFO  d38aa58d
# 53      54  INFO  e3df2680
# 54      55  INFO  09a53393
# 55      56  INFO  09a53393
# 56      57  INFO  d38aa58d
# 57      58  INFO  e3df2680
# 58      59  INFO  09a53393
# 59      60  INFO  d38aa58d
#
#                                                                        EventTemplate  \
# 0                                             Receiving block <*> src: <*> dest: <*>
# 1                                             Receiving block <*> src: <*> dest: <*>
# 2                                             Receiving block <*> src: <*> dest: <*>
# 3                                             Receiving block <*> src: <*> dest: <*>
# 4                                             Receiving block <*> src: <*> dest: <*>
# 5                                             Receiving block <*> src: <*> dest: <*>
# 6                                                     Verification succeeded for <*>
# 7   BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 8                                           BLOCK* NameSystem.allocateBlock: <*> <*>
# 9   BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 10  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 11  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 12  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 13  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 14  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 15  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 16                                          BLOCK* NameSystem.allocateBlock: <*> <*>
# 17  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 18  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 19  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 20                                          BLOCK* NameSystem.allocateBlock: <*> <*>
# 21  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 22  BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 23                                          BLOCK* NameSystem.allocateBlock: <*> <*>
# 24                                             PacketResponder <*> for block <*> <*>
# 25                                           Received block <*> of size <*> from <*>
# 26                                             PacketResponder <*> for block <*> <*>
# 27                                           Received block <*> of size <*> from <*>
# 28                                             PacketResponder <*> for block <*> <*>
# 29                                           Received block <*> of size <*> from <*>
# 30                                             PacketResponder <*> for block <*> <*>
# 31                                           Received block <*> of size <*> from <*>
# 32                                            Receiving block <*> src: <*> dest: <*>
# 33                                             PacketResponder <*> for block <*> <*>
# 34                                             PacketResponder <*> for block <*> <*>
# 35                                           Received block <*> of size <*> from <*>
# 36                                           Received block <*> of size <*> from <*>
# 37                                             PacketResponder <*> for block <*> <*>
# 38                                           Received block <*> of size <*> from <*>
# 39                                             PacketResponder <*> for block <*> <*>
# 40                                             PacketResponder <*> for block <*> <*>
# 41                                           Received block <*> of size <*> from <*>
# 42                                           Received block <*> of size <*> from <*>
# 43                                             PacketResponder <*> for block <*> <*>
# 44                                           Received block <*> of size <*> from <*>
# 45                                             PacketResponder <*> for block <*> <*>
# 46                                           Received block <*> of size <*> from <*>
# 47                                             PacketResponder <*> for block <*> <*>
# 48                                           Received block <*> of size <*> from <*>
# 49                                            Receiving block <*> src: <*> dest: <*>
# 50                                             PacketResponder <*> for block <*> <*>
# 51                                           Received block <*> of size <*> from <*>
# 52                                             PacketResponder <*> for block <*> <*>
# 53                                           Received block <*> of size <*> from <*>
# 54                                            Receiving block <*> src: <*> dest: <*>
# 55                                            Receiving block <*> src: <*> dest: <*>
# 56                                             PacketResponder <*> for block <*> <*>
# 57                                           Received block <*> of size <*> from <*>
# 58                                            Receiving block <*> src: <*> dest: <*>
# 59                                             PacketResponder <*> for block <*> <*>
#
#    IDLevel LineId2
# 0       I1      L1
# 1       I1      L1
# 2       I1      L1
# 3       I1      L1
# 4       I1      L1
# 5       I1      L1
# 6      I13     L13
# 7       I5      L5
# 8       I2      L2
# 9       I5      L5
# 10      I5      L5
# 11      I5      L5
# 12      I5      L5
# 13      I5      L5
# 14      I5      L5
# 15      I5      L5
# 16      I2      L2
# 17      I5      L5
# 18      I5      L5
# 19      I5      L5
# 20      I2      L2
# 21      I5      L5
# 22      I5      L5
# 23      I2      L2
# 24      I3      L3
# 25      I4      L4
# 26      I3      L3
# 27      I4      L4
# 28      I3      L3
# 29      I4      L4
# 30      I3      L3
# 31      I4      L4
# 32      I1      L1
# 33      I3      L3
# 34      I3      L3
# 35      I4      L4
# 36      I4      L4
# 37      I3      L3
# 38      I4      L4
# 39      I3      L3
# 40      I3      L3
# 41      I4      L4
# 42      I4      L4
# 43      I3      L3
# 44      I4      L4
# 45      I3      L3
# 46      I4      L4
# 47      I3      L3
# 48      I4      L4
# 49      I1      L1
# 50      I3      L3
# 51      I4      L4
# 52      I3      L3
# 53      I4      L4
# 54      I1      L1
# 55      I1      L1
# 56      I3      L3
# 57      I4      L4
# 58      I1      L1
# 59      I3      L3
# File đầu vào: ../../Dataset/HDFS/v1/test3.log
# Total lines:  200500
# Processed 49.9% of log lines.
# Processed 99.8% of log lines.
# Processed 100.0% of log lines.
# Phân tích hoàn thành! [Thời gian thực hiện: 0:00:13.852110]
#     LineId Level   EventId  \
# 0        1  INFO  d38aa58d
# 1        2  INFO  e3df2680
# 2        3  INFO  09a53393
# 3        4  INFO  09a53393
# 4        5  INFO  09a53393
# 5        6  INFO  d38aa58d
# 6        7  INFO  e3df2680
# 7        8  INFO  d38aa58d
# 8        9  INFO  e3df2680
# 9       10  INFO  09a53393
# 10      11  INFO  d38aa58d
# 11      12  INFO  e3df2680
# 12      13  INFO  d38aa58d
# 13      14  INFO  e3df2680
# 14      15  INFO  d38aa58d
# 15      16  INFO  e3df2680
# 16      17  INFO  d38aa58d
# 17      18  INFO  e3df2680
# 18      19  INFO  d38aa58d
# 19      20  INFO  e3df2680
# 20      21  INFO  09a53393
# 21      22  INFO  09a53393
# 22      23  INFO  09a53393
# 23      24  INFO  09a53393
# 24      25  INFO  09a53393
# 25      26  INFO  09a53393
# 26      27  INFO  09a53393
# 27      28  INFO  d38aa58d
# 28      29  INFO  e3df2680
# 29      30  INFO  09a53393
# 30      31  INFO  5d5de21c
# 31      32  INFO  5d5de21c
# 32      33  INFO  5d5de21c
# 33      34  INFO  3d91fa85
# 34      35  INFO  5d5de21c
# 35      36  INFO  5d5de21c
# 36      37  INFO  5d5de21c
# 37      38  INFO  3d91fa85
# 38      39  INFO  5d5de21c
# 39      40  INFO  3d91fa85
# 40      41  INFO  5d5de21c
# 41      42  INFO  5d5de21c
# 42      43  INFO  5d5de21c
# 43      44  INFO  5d5de21c
# 44      45  INFO  3d91fa85
# 45      46  WARN  c294d20f
# 46      47  WARN  c294d20f
# 47      48  INFO  5d5de21c
# 48      49  INFO  5d5de21c
# 49      50  INFO  3d91fa85
# 50      51  INFO  5d5de21c
# 51      52  INFO  5d5de21c
# 52      53  INFO  5d5de21c
# 53      54  INFO  5d5de21c
# 54      55  INFO  5d5de21c
# 55      56  INFO  5d5de21c
# 56      57  INFO  3d91fa85
# 57      58  INFO  5d5de21c
# 58      59  INFO  3d91fa85
# 59      60  INFO  5d5de21c
#
#                                                                                           EventTemplate  \
# 0                                                                 PacketResponder <*> for block <*> <*>
# 1                                                               Received block <*> of size <*> from <*>
# 2                                                                Receiving block <*> src: <*> dest: <*>
# 3                                                                Receiving block <*> src: <*> dest: <*>
# 4                                                                Receiving block <*> src: <*> dest: <*>
# 5                                                                 PacketResponder <*> for block <*> <*>
# 6                                                               Received block <*> of size <*> from <*>
# 7                                                                 PacketResponder <*> for block <*> <*>
# 8                                                               Received block <*> of size <*> from <*>
# 9                                                                Receiving block <*> src: <*> dest: <*>
# 10                                                                PacketResponder <*> for block <*> <*>
# 11                                                              Received block <*> of size <*> from <*>
# 12                                                                PacketResponder <*> for block <*> <*>
# 13                                                              Received block <*> of size <*> from <*>
# 14                                                                PacketResponder <*> for block <*> <*>
# 15                                                              Received block <*> of size <*> from <*>
# 16                                                                PacketResponder <*> for block <*> <*>
# 17                                                              Received block <*> of size <*> from <*>
# 18                                                                PacketResponder <*> for block <*> <*>
# 19                                                              Received block <*> of size <*> from <*>
# 20                                                               Receiving block <*> src: <*> dest: <*>
# 21                                                               Receiving block <*> src: <*> dest: <*>
# 22                                                               Receiving block <*> src: <*> dest: <*>
# 23                                                               Receiving block <*> src: <*> dest: <*>
# 24                                                               Receiving block <*> src: <*> dest: <*>
# 25                                                               Receiving block <*> src: <*> dest: <*>
# 26                                                               Receiving block <*> src: <*> dest: <*>
# 27                                                                PacketResponder <*> for block <*> <*>
# 28                                                              Received block <*> of size <*> from <*>
# 29                                                               Receiving block <*> src: <*> dest: <*>
# 30                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 31                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 32                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 33                                                             BLOCK* NameSystem.allocateBlock: <*> <*>
# 34                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 35                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 36                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 37                                                             BLOCK* NameSystem.allocateBlock: <*> <*>
# 38                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 39                                                             BLOCK* NameSystem.allocateBlock: <*> <*>
# 40                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 41                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 42                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 43                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 44                                                             BLOCK* NameSystem.allocateBlock: <*> <*>
# 45  BLOCK* NameSystem.addStoredBlock: Redundant addStoredBlock request received for <*> on <*> size <*>
# 46  BLOCK* NameSystem.addStoredBlock: Redundant addStoredBlock request received for <*> on <*> size <*>
# 47                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 48                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 49                                                             BLOCK* NameSystem.allocateBlock: <*> <*>
# 50                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 51                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 52                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 53                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 54                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 55                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 56                                                             BLOCK* NameSystem.allocateBlock: <*> <*>
# 57                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 58                                                             BLOCK* NameSystem.allocateBlock: <*> <*>
# 59                     BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
#
#    IDLevel LineId2
# 0       I3      L3
# 1       I4      L4
# 2       I1      L1
# 3       I1      L1
# 4       I1      L1
# 5       I3      L3
# 6       I4      L4
# 7       I3      L3
# 8       I4      L4
# 9       I1      L1
# 10      I3      L3
# 11      I4      L4
# 12      I3      L3
# 13      I4      L4
# 14      I3      L3
# 15      I4      L4
# 16      I3      L3
# 17      I4      L4
# 18      I3      L3
# 19      I4      L4
# 20      I1      L1
# 21      I1      L1
# 22      I1      L1
# 23      I1      L1
# 24      I1      L1
# 25      I1      L1
# 26      I1      L1
# 27      I3      L3
# 28      I4      L4
# 29      I1      L1
# 30      I5      L5
# 31      I5      L5
# 32      I5      L5
# 33      I2      L2
# 34      I5      L5
# 35      I5      L5
# 36      I5      L5
# 37      I2      L2
# 38      I5      L5
# 39      I2      L2
# 40      I5      L5
# 41      I5      L5
# 42      I5      L5
# 43      I5      L5
# 44      I2      L2
# 45      W1     L21
# 46      W1     L21
# 47      I5      L5
# 48      I5      L5
# 49      I2      L2
# 50      I5      L5
# 51      I5      L5
# 52      I5      L5
# 53      I5      L5
# 54      I5      L5
# 55      I5      L5
# 56      I2      L2
# 57      I5      L5
# 58      I2      L2
# 59      I5      L5
# File đầu vào: ../../Dataset/HDFS/v1/test4.log
# Total lines:  200500
# Processed 49.9% of log lines.
# Processed 99.8% of log lines.
# Processed 100.0% of log lines.
# Phân tích hoàn thành! [Thời gian thực hiện: 0:00:14.309842]
#     LineId Level   EventId                              EventTemplate IDLevel  \
# 0        1  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 1        2  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 2        3  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 3        4  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 4        5  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 5        6  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 6        7  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 7        8  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 8        9  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 9       10  INFO  626085d5                <*> Served block <*> to <*>     I10
# 10      11  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 11      12  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 12      13  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 13      14  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 14      15  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 15      16  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 16      17  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 17      18  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 18      19  INFO  32777b38             Verification succeeded for <*>     I13
# 19      20  INFO  32777b38             Verification succeeded for <*>     I13
# 20      21  INFO  32777b38             Verification succeeded for <*>     I13
# 21      22  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 22      23  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 23      24  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 24      25  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 25      26  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 26      27  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 27      28  INFO  626085d5                <*> Served block <*> to <*>     I10
# 28      29  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 29      30  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 30      31  INFO  626085d5                <*> Served block <*> to <*>     I10
# 31      32  INFO  626085d5                <*> Served block <*> to <*>     I10
# 32      33  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 33      34  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 34      35  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 35      36  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 36      37  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 37      38  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 38      39  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 39      40  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 40      41  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 41      42  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 42      43  INFO  626085d5                <*> Served block <*> to <*>     I10
# 43      44  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 44      45  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 45      46  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 46      47  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 47      48  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 48      49  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 49      50  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 50      51  INFO  32777b38             Verification succeeded for <*>     I13
# 51      52  INFO  32777b38             Verification succeeded for <*>     I13
# 52      53  INFO  32777b38             Verification succeeded for <*>     I13
# 53      54  INFO  32777b38             Verification succeeded for <*>     I13
# 54      55  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 55      56  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 56      57  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 57      58  WARN  81cee340  <*>Got exception while serving <*> to <*>      W4
# 58      59  INFO  626085d5                <*> Served block <*> to <*>     I10
# 59      60  INFO  626085d5                <*> Served block <*> to <*>     I10
#
#    LineId2
# 0      L35
# 1      L35
# 2      L35
# 3      L35
# 4      L35
# 5      L35
# 6      L35
# 7      L35
# 8      L35
# 9      L10
# 10     L35
# 11     L35
# 12     L35
# 13     L35
# 14     L35
# 15     L35
# 16     L35
# 17     L35
# 18     L13
# 19     L13
# 20     L13
# 21     L35
# 22     L35
# 23     L35
# 24     L35
# 25     L35
# 26     L35
# 27     L10
# 28     L35
# 29     L35
# 30     L10
# 31     L10
# 32     L35
# 33     L35
# 34     L35
# 35     L35
# 36     L35
# 37     L35
# 38     L35
# 39     L35
# 40     L35
# 41     L35
# 42     L10
# 43     L35
# 44     L35
# 45     L35
# 46     L35
# 47     L35
# 48     L35
# 49     L35
# 50     L13
# 51     L13
# 52     L13
# 53     L13
# 54     L35
# 55     L35
# 56     L35
# 57     L35
# 58     L10
# 59     L10
# File đầu vào: ../../Dataset/HDFS/v1/test5.log
# Total lines:  198999
# Processed 50.3% of log lines.
# Processed 100.0% of log lines.
# Phân tích hoàn thành! [Thời gian thực hiện: 0:00:14.086164]
#     LineId Level   EventId  \
# 0        1  INFO  5d5de21c
# 1        2  INFO  3d91fa85
# 2        3  INFO  3d91fa85
# 3        4  INFO  5d5de21c
# 4        5  INFO  5d5de21c
# 5        6  INFO  5d5de21c
# 6        7  INFO  5d5de21c
# 7        8  INFO  3d91fa85
# 8        9  INFO  3d91fa85
# 9       10  INFO  09a53393
# 10      11  INFO  e3df2680
# 11      12  INFO  d38aa58d
# 12      13  INFO  e3df2680
# 13      14  INFO  09a53393
# 14      15  INFO  09a53393
# 15      16  INFO  d38aa58d
# 16      17  INFO  d38aa58d
# 17      18  INFO  e3df2680
# 18      19  INFO  09a53393
# 19      20  INFO  09a53393
# 20      21  INFO  d38aa58d
# 21      22  INFO  e3df2680
# 22      23  INFO  09a53393
# 23      24  INFO  d38aa58d
# 24      25  INFO  e3df2680
# 25      26  INFO  d38aa58d
# 26      27  INFO  e3df2680
# 27      28  INFO  09a53393
# 28      29  INFO  09a53393
# 29      30  INFO  e3df2680
# 30      31  INFO  d38aa58d
# 31      32  INFO  e3df2680
# 32      33  INFO  09a53393
# 33      34  INFO  09a53393
# 34      35  INFO  d38aa58d
# 35      36  INFO  e3df2680
# 36      37  INFO  09a53393
# 37      38  INFO  09a53393
# 38      39  INFO  d38aa58d
# 39      40  INFO  e3df2680
# 40      41  INFO  d38aa58d
# 41      42  INFO  e3df2680
# 42      43  INFO  d38aa58d
# 43      44  INFO  e3df2680
# 44      45  INFO  09a53393
# 45      46  INFO  09a53393
# 46      47  INFO  09a53393
# 47      48  INFO  09a53393
# 48      49  INFO  09a53393
# 49      50  INFO  d38aa58d
# 50      51  INFO  d38aa58d
# 51      52  INFO  e3df2680
# 52      53  INFO  e3df2680
# 53      54  INFO  09a53393
# 54      55  INFO  09a53393
# 55      56  INFO  d38aa58d
# 56      57  INFO  e3df2680
# 57      58  INFO  09a53393
# 58      59  INFO  d38aa58d
# 59      60  INFO  e3df2680
#
#                                                                        EventTemplate  \
# 0   BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 1                                           BLOCK* NameSystem.allocateBlock: <*> <*>
# 2                                           BLOCK* NameSystem.allocateBlock: <*> <*>
# 3   BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 4   BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 5   BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 6   BLOCK* NameSystem.addStoredBlock: blockMap updated: <*> is added to <*> size <*>
# 7                                           BLOCK* NameSystem.allocateBlock: <*> <*>
# 8                                           BLOCK* NameSystem.allocateBlock: <*> <*>
# 9                                             Receiving block <*> src: <*> dest: <*>
# 10                                           Received block <*> of size <*> from <*>
# 11                                             PacketResponder <*> for block <*> <*>
# 12                                           Received block <*> of size <*> from <*>
# 13                                            Receiving block <*> src: <*> dest: <*>
# 14                                            Receiving block <*> src: <*> dest: <*>
# 15                                             PacketResponder <*> for block <*> <*>
# 16                                             PacketResponder <*> for block <*> <*>
# 17                                           Received block <*> of size <*> from <*>
# 18                                            Receiving block <*> src: <*> dest: <*>
# 19                                            Receiving block <*> src: <*> dest: <*>
# 20                                             PacketResponder <*> for block <*> <*>
# 21                                           Received block <*> of size <*> from <*>
# 22                                            Receiving block <*> src: <*> dest: <*>
# 23                                             PacketResponder <*> for block <*> <*>
# 24                                           Received block <*> of size <*> from <*>
# 25                                             PacketResponder <*> for block <*> <*>
# 26                                           Received block <*> of size <*> from <*>
# 27                                            Receiving block <*> src: <*> dest: <*>
# 28                                            Receiving block <*> src: <*> dest: <*>
# 29                                           Received block <*> of size <*> from <*>
# 30                                             PacketResponder <*> for block <*> <*>
# 31                                           Received block <*> of size <*> from <*>
# 32                                            Receiving block <*> src: <*> dest: <*>
# 33                                            Receiving block <*> src: <*> dest: <*>
# 34                                             PacketResponder <*> for block <*> <*>
# 35                                           Received block <*> of size <*> from <*>
# 36                                            Receiving block <*> src: <*> dest: <*>
# 37                                            Receiving block <*> src: <*> dest: <*>
# 38                                             PacketResponder <*> for block <*> <*>
# 39                                           Received block <*> of size <*> from <*>
# 40                                             PacketResponder <*> for block <*> <*>
# 41                                           Received block <*> of size <*> from <*>
# 42                                             PacketResponder <*> for block <*> <*>
# 43                                           Received block <*> of size <*> from <*>
# 44                                            Receiving block <*> src: <*> dest: <*>
# 45                                            Receiving block <*> src: <*> dest: <*>
# 46                                            Receiving block <*> src: <*> dest: <*>
# 47                                            Receiving block <*> src: <*> dest: <*>
# 48                                            Receiving block <*> src: <*> dest: <*>
# 49                                             PacketResponder <*> for block <*> <*>
# 50                                             PacketResponder <*> for block <*> <*>
# 51                                           Received block <*> of size <*> from <*>
# 52                                           Received block <*> of size <*> from <*>
# 53                                            Receiving block <*> src: <*> dest: <*>
# 54                                            Receiving block <*> src: <*> dest: <*>
# 55                                             PacketResponder <*> for block <*> <*>
# 56                                           Received block <*> of size <*> from <*>
# 57                                            Receiving block <*> src: <*> dest: <*>
# 58                                             PacketResponder <*> for block <*> <*>
# 59                                           Received block <*> of size <*> from <*>
#
#    IDLevel LineId2
# 0       I5      L5
# 1       I2      L2
# 2       I2      L2
# 3       I5      L5
# 4       I5      L5
# 5       I5      L5
# 6       I5      L5
# 7       I2      L2
# 8       I2      L2
# 9       I1      L1
# 10      I4      L4
# 11      I3      L3
# 12      I4      L4
# 13      I1      L1
# 14      I1      L1
# 15      I3      L3
# 16      I3      L3
# 17      I4      L4
# 18      I1      L1
# 19      I1      L1
# 20      I3      L3
# 21      I4      L4
# 22      I1      L1
# 23      I3      L3
# 24      I4      L4
# 25      I3      L3
# 26      I4      L4
# 27      I1      L1
# 28      I1      L1
# 29      I4      L4
# 30      I3      L3
# 31      I4      L4
# 32      I1      L1
# 33      I1      L1
# 34      I3      L3
# 35      I4      L4
# 36      I1      L1
# 37      I1      L1
# 38      I3      L3
# 39      I4      L4
# 40      I3      L3
# 41      I4      L4
# 42      I3      L3
# 43      I4      L4
# 44      I1      L1
# 45      I1      L1
# 46      I1      L1
# 47      I1      L1
# 48      I1      L1
# 49      I3      L3
# 50      I3      L3
# 51      I4      L4
# 52      I4      L4
# 53      I1      L1
# 54      I1      L1
# 55      I3      L3
# 56      I4      L4
# 57      I1      L1
# 58      I3      L3
# 59      I4      L4
